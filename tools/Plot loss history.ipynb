# %%
directory = '/code/ThesisProject-SCFasterRCNN9000/experiments/logs'
logFile = 'faster_rcnn_end2end_.txt.2017-05-08_14-42-18'
import os
import re
import matplotlib.pyplot as plt
import numpy as np
from jupyterthemes import jtplot
import seaborn as sns
# %matplotlib inline

# %%
with open(os.path.join(directory,logFile),'rb') as w:
    text = w.read()
    trainLoss = [float(text[m.end():m.end()+6]) for m in re.finditer('total loss: ', text)]

# %%
plt.figure(figsize=(15,8))
plt.plot(trainLoss)
#plt.axis([0, len(trainLoss), 0, np.max(trainLoss)])

# %%
os.chdir(directory)
sorted(filter(os.path.isfile, os.listdir('.')), key=os.path.getmtime)
# Out:
# ['faster_rcnn_end2end_VGG16_.txt.2017-03-24_15-51-50',
#  'faster_rcnn_end2end_VGG16_.txt.2017-03-24_15-56-32',
#  'faster_rcnn_end2end_VGG16_.txt.2017-03-24_15-58-31',
#  'faster_rcnn_end2end_VGG16_.txt.2017-03-24_15-59-33',
#  'faster_rcnn_end2end_VGG16_.txt.2017-03-24_16-00-15',
#  'faster_rcnn_end2end_VGG16_.txt.2017-03-27_07-39-03',
#  'faster_rcnn_end2end_VGG16_.txt.2017-03-27_07-49-27',
#  'faster_rcnn_end2end_VGG16_.txt.2017-03-27_07-52-32',
#  'faster_rcnn_end2end_VGG16_.txt.2017-03-27_07-54-14',
#  'faster_rcnn_end2end_VGG16_.txt.2017-03-27_08-03-43',
#  'faster_rcnn_end2end_VGG16_.txt.2017-03-27_08-06-35',
#  'faster_rcnn_end2end_VGG16_.txt.2017-03-27_08-07-20',
#  'faster_rcnn_end2end_VGG16_.txt.2017-03-27_08-08-51',
#  'faster_rcnn_end2end_VGG16_.txt.2017-03-27_08-16-44',
#  'faster_rcnn_end2end_VGG16_.txt.2017-03-27_08-16-52',
#  'faster_rcnn_end2end_VGG16_.txt.2017-03-27_08-22-32',
#  'faster_rcnn_end2end_VGG16_.txt.2017-03-27_08-27-53',
# ...
